# %%
import sqlite3
import pandas as pd

# %%
c = sqlite3.connect('position_tracker.db')
sql = '''
select * from position_table
'''
df = pd.read_sql(sql, c)
c.close()
df
# Out:
#                 Month  Employee # Filled Position Description  \
# 0            April-17      3504.0              ASST CITY ATTY
# 1            April-17      2114.0           LITIGATION ASST 1
# 2            April-17      1351.0                 CLERK-TYP 2
# 3            April-17      3630.0              ASST CITY ATTY
# 4            April-17      3074.0           SECRETARY 3-LEGAL
# 5            April-17      2963.0                   ATTY CITY
# 6            April-17      3669.0              ASST CITY ATTY
# 7            April-17      1121.0           LEGAL OFFICE ASST
# 8            April-17      2665.0           SECRETARY 2-LEGAL
# 9            April-17      1381.0              ASST CITY ATTY
# 10           April-17      1215.0          ORD REVISIONS SPEC
# 11           April-17      2320.0              ASST CITY ATTY
# 12           April-17      1288.0            DEPUTY CITY ATTY
# 13           April-17      1249.0           SECRETARY 2-LEGAL
# ...

# %%
c = sqlite3.connect('position_tracker.db')
sql = '''
select distinct "Filled Position Description" from position_table
'''
df = pd.read_sql(sql, c)
c.close()
df
# Out:
#       Filled Position Description
# 0                  ASST CITY ATTY
# 1               LITIGATION ASST 1
# 2                     CLERK-TYP 2
# 3               SECRETARY 3-LEGAL
# 4                       ATTY CITY
# 5               LEGAL OFFICE ASST
# 6               SECRETARY 2-LEGAL
# 7              ORD REVISIONS SPEC
# 8                DEPUTY CITY ATTY
# 9                        ALDERMAN
# 10              COUNCIL PRESIDENT
# 11        COUNCIL PRES PRO TEM-19
# 12                     ADMIN ASST
# 13                    SECRETARY 1
# 14                  SECY TO MAYOR
# 15                MAYORAL OFF CLK
# 16                 DEPUTY MAYOR 2
# 17                          MAYOR
# 18           MAYOR'S OFF ADMIN CO
# 19                         AA MGR
# 20                AFF ACTION SPEC
# 21                          CCS 2
# 22                 PROGRAM ASST 1
# 23                  DR & SP COORD
# 24                  M.T. DIRECTOR
# 25            M.T. ASSOC DIRECTOR
# ...

# %%
c = sqlite3.connect('position_tracker.db')
sql = '''
select distinct "Filled Position Description" from position_table
'''
df = pd.read_sql(sql, c)
c.close()
df
